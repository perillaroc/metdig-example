# %%
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # 1. 环流条件分析

# %%
import nmc_met_map.synoptic as draw_synoptic

# %%
draw_synoptic.gh_uv_mslp(map_ratio=19/9)

# %%
draw_synoptic.gh_uv_wsp()
